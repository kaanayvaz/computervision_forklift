# %% [markdown]
# # Forklift Analytics - Exploration Notebook
#
# Use this notebook to:
# - Test detection on sample frames
# - Visualize tracking results
# - Tune thresholds interactively
# - Debug pipeline components

# %%
# Setup
import sys
from pathlib import Path

# Add src to path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root / "src"))

import cv2
import numpy as np
from matplotlib import pyplot as plt

# Enable inline plots
# %matplotlib inline

# %%
# Load sample video and extract frame
video_path = project_root / "data" / "sample_videos" / "test.mp4"

if video_path.exists():
    cap = cv2.VideoCapture(str(video_path))
    ret, frame = cap.read()
    cap.release()
    
    if ret:
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(12, 8))
        plt.imshow(frame_rgb)
        plt.title("Sample Frame")
        plt.axis("off")
        plt.show()
else:
    print(f"Video not found: {video_path}")
    print("Place a sample video in data/sample_videos/")

# %%
# TODO: Test detection
# from detection.detector import ForkliftDetector
# detector = ForkliftDetector("config/inference.yaml")
# detections = detector.detect_frame(frame)
